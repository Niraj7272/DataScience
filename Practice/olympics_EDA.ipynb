# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DataSet/olympics.csv')
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# 0               China  CHN  1992 Summer  1992  Summer  Barcelona
# 1               China  CHN  2012 Summer  2012  Summer     London
# 2             Denmark  DEN  1920 Summer  1920  Summer  Antwerpen
# 3      Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris
# 4         Netherlands  NED  1988 Winter  1988  Winter    Calgary
# ...               ...  ...          ...   ...     ...        ...
# 69995   Great Britain  GBR  1976 Winter  1976  Winter  Innsbruck
# 69996   Great Britain  GBR  1976 Winter  1976  Winter  Innsbruck
# 69997       Australia  AUS  1976 Summer  1976  Summer   Montreal
# 69998       Australia  AUS  1980 Summer  1980  Summer     Moskva
# 69999  Czech Republic  CZE  1998 Winter  1998  Winter     Nagano
#
#                  Sport                             Event Medal
# 0           Basketball       Basketball Men's Basketball   NaN
# 1                 Judo      Judo Men's Extra-Lightweight   NaN
# 2             Football           Football Men's Football   NaN
# 3           Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4        Speed Skating  Speed Skating Women's 500 metres   NaN
# ...                ...                               ...   ...
# 69995    Alpine Skiing  Alpine Skiing Men's Giant Slalom   NaN
# 69996    Alpine Skiing        Alpine Skiing Men's Slalom   NaN
# 69997        Athletics     Athletics Men's 10,000 metres   NaN
# 69998        Athletics      Athletics Men's 5,000 metres   NaN
# 69999  Nordic Combined        Nordic Combined Men's Team   NaN
#
# [70000 rows x 15 columns]

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      70000 non-null  int64
#  1   Name    70000 non-null  object
#  2   Sex     70000 non-null  object
#  3   Age     67268 non-null  float64
#  4   Height  53746 non-null  float64
#  5   Weight  52899 non-null  float64
#  6   Team    70000 non-null  object
#  7   NOC     70000 non-null  object
#  8   Games   70000 non-null  object
#  9   Year    70000 non-null  int64
#  10  Season  70000 non-null  object
#  11  City    70000 non-null  object
#  12  Sport   70000 non-null  object
#  13  Event   70000 non-null  object
#  14  Medal   9690 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 8.0+ MB

# %%
df.describe()
# Out:
#                  ID           Age        Height        Weight          Year
# count  70000.000000  67268.000000  53746.000000  52899.000000  70000.000000
# mean   18081.846986     25.644645    175.505303     70.900216   1977.766457
# std    10235.613253      6.485239     10.384203     14.217489     30.103306
# min        1.000000     11.000000    127.000000     25.000000   1896.000000
# 25%     9325.750000     21.000000    168.000000     61.000000   1960.000000
# 50%    18032.000000     25.000000    175.000000     70.000000   1984.000000
# 75%    26978.000000     28.000000    183.000000     79.000000   2002.000000
# max    35658.000000     88.000000    223.000000    214.000000   2016.000000

# %%
df.describe(include=['object'])
# Out:
#                                     Name    Sex           Team    NOC  \
# count                              70000  70000          70000  70000
# unique                             35556      2            827    226
# top     Oksana Aleksandrovna Chusovitina      M  United States    USA
# freq                                  29  51877           4979   5216
#
#               Games  Season    City      Sport                    Event Medal
# count         70000   70000   70000      70000                    70000  9690
# unique           51       2      42         65                      744     3
# top     2016 Summer  Summer  London  Athletics  Football Men's Football  Gold
# freq           3675   58467    6034      10629                     1738  3292

# %%
df.isna().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        2732
# Height    16254
# Weight    17101
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     60310
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(383)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.countplot(data=df, x='Sex')
plt.title('Distribution by Gender')
plt.show()

# %%
sns.histplot(data=df, x='Age', bins=20, kde=True)
plt.title('Age Distribution')
plt.show()

# %%
sns.histplot(data=df, x='Height', bins = 20, kde=True)
plt.title('Hight Distributon')
plt.show()

# %%
sns.histplot(data=df, x='Weight', bins= 20, kde=True)
plt.title("Weight Distribution")
plt.show()

# %%
sns.countplot(data=df, x="Medal")
plt.title('Medals Distribution')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df, x='Year', hue='Medal')
plt.title("Medal Distribution Over the Years")
plt.xticks(rotation= 45)
plt.show()

# %%
year_avg_age=df.groupby('Year')['Age'].mean()
print(year_avg_age)
# Out:
# Year
# 1896    23.029412
# 1900    29.119883
# 1904    27.063241
# 1906    26.989474
# 1908    27.000000
# 1912    27.965552
# 1920    29.241135
# 1924    28.252267
# 1928    27.973564
# 1932    29.606987
# 1936    27.245665
# 1948    28.363170
# 1952    26.273684
# 1956    26.316156
# 1960    25.136156
# 1964    24.852107
# 1968    24.316722
# 1972    24.126448
# 1976    23.656820
# 1980    23.312364
# 1984    24.060328
# 1988    24.257374
# 1992    24.637827
# 1994    24.487516
# 1996    25.338210
# 1998    25.143860
# 2000    25.435177
# 2002    26.029095
# 2004    25.780111
# 2006    26.091716
# 2008    25.685148
# 2010    26.150776
# 2012    25.993485
# 2014    26.082814
# 2016    26.259592
# Name: Age, dtype: float64

# %%
sport_median_height = df.groupby('Sport')['Height'].median()
print(sport_median_height)
# Out:
# Sport
# Alpine Skiing       173.0
# Alpinism              NaN
# Archery             172.0
# Art Competitions    183.0
# Athletics           176.0
#                     ...
# Tug-Of-War          182.0
# Volleyball          187.5
# Water Polo          185.0
# Weightlifting       168.0
# Wrestling           172.0
# Name: Height, Length: 65, dtype: float64

# %%
print(sport_median_height.max())
# Out:
# 190.0

# %%
print(sport_median_height.idxmax())
# Out:
# Basketball

# %%
sport_median_height
# Out:
# Sport
# Alpine Skiing       173.0
# Alpinism              NaN
# Archery             172.0
# Art Competitions    183.0
# Athletics           176.0
#                     ...
# Tug-Of-War          182.0
# Volleyball          187.5
# Water Polo          185.0
# Weightlifting       168.0
# Wrestling           172.0
# Name: Height, Length: 65, dtype: float64

# %%
sport_median_height == 190.0
# Out:
# Sport
# Alpine Skiing       False
# Alpinism            False
# Archery             False
# Art Competitions    False
# Athletics           False
#                     ...
# Tug-Of-War          False
# Volleyball          False
# Water Polo          False
# Weightlifting       False
# Wrestling           False
# Name: Height, Length: 65, dtype: bool

# %%
sport_median_height[sport_median_height == 190.0]
# Out:
# Sport
# Basketball    190.0
# Name: Height, dtype: float64

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
list(df.groupby('Season'))
# Out:
# [('Summer',
#             ID                                Name Sex   Age  Height  Weight  \
#   0          1                           A Dijiang   M  24.0   180.0    80.0
#   1          2                            A Lamusi   M  23.0   170.0    60.0
#   2          3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
#   3          4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
#   26         8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#   ...      ...                                 ...  ..   ...     ...     ...
#   69984  35652                     Tom Fitzpatrick   M  29.0   176.0    73.0
#   69992  35654           Patrick "Pat" Fitzsimmons   M  20.0   160.0    56.0
#   69993  35655                   Riley Fitzsimmons   M  20.0   192.0    93.0
#   69997  35657      David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
#   69998  35657      David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
#
#                    Team  NOC        Games  Year  Season            City  \
#   0               China  CHN  1992 Summer  1992  Summer       Barcelona
#   1               China  CHN  2012 Summer  2012  Summer          London
#   2             Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
#   3      Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
#   26        Netherlands  NED  1932 Summer  1932  Summer     Los Angeles
#   ...               ...  ...          ...   ...     ...             ...
#   69984         Ireland  IRL  2004 Summer  2004  Summer          Athina
#   69992         Ireland  IRL  1964 Summer  1964  Summer           Tokyo
#   69993       Australia  AUS  2016 Summer  2016  Summer  Rio de Janeiro
#   69997       Australia  AUS  1976 Summer  1976  Summer        Montreal
#   69998       Australia  AUS  1980 Summer  1980  Summer          Moskva
#
#               Sport                                     Event Medal
#   0      Basketball               Basketball Men's Basketball   NaN
#   1            Judo              Judo Men's Extra-Lightweight   NaN
#   2        Football                   Football Men's Football   NaN
#   3      Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
#   26      Athletics              Athletics Women's 100 metres   NaN
#   ...           ...                                       ...   ...
#   69984     Sailing                       Sailing Mixed Skiff   NaN
#   69992      Boxing                Boxing Men's Featherweight   NaN
#   69993    Canoeing  Canoeing Men's Kayak Fours, 1,000 metres   NaN
#   69997   Athletics             Athletics Men's 10,000 metres   NaN
#   69998   Athletics              Athletics Men's 5,000 metres   NaN
#
#   [58084 rows x 15 columns]),
#  ('Winter',
#             ID                      Name Sex   Age  Height  Weight  \
#   4          5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
#   5          5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
#   6          5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
#   7          5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
#   8          5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
#   ...      ...                       ...  ..   ...     ...     ...
#   69991  35653     Casey J. FitzRandolph   M  31.0   180.0    79.0
#   69994  35656        Stuart Fitzsimmons   M  19.0     NaN     NaN
#   69995  35656        Stuart Fitzsimmons   M  19.0     NaN     NaN
#   69996  35656        Stuart Fitzsimmons   M  19.0     NaN     NaN
#   69999  35658              Marek Fiurek   M  23.0   180.0    68.0
#
#                    Team  NOC        Games  Year  Season         City  \
#   4         Netherlands  NED  1988 Winter  1988  Winter      Calgary
#   5         Netherlands  NED  1988 Winter  1988  Winter      Calgary
#   6         Netherlands  NED  1992 Winter  1992  Winter  Albertville
#   7         Netherlands  NED  1992 Winter  1992  Winter  Albertville
#   8         Netherlands  NED  1994 Winter  1994  Winter  Lillehammer
#   ...               ...  ...          ...   ...     ...          ...
#   69991   United States  USA  2006 Winter  2006  Winter       Torino
#   69994   Great Britain  GBR  1976 Winter  1976  Winter    Innsbruck
#   69995   Great Britain  GBR  1976 Winter  1976  Winter    Innsbruck
#   69996   Great Britain  GBR  1976 Winter  1976  Winter    Innsbruck
#   69999  Czech Republic  CZE  1998 Winter  1998  Winter       Nagano
#
#                    Sport                               Event Medal
#   4        Speed Skating    Speed Skating Women's 500 metres   NaN
#   5        Speed Skating  Speed Skating Women's 1,000 metres   NaN
#   6        Speed Skating    Speed Skating Women's 500 metres   NaN
#   7        Speed Skating  Speed Skating Women's 1,000 metres   NaN
#   8        Speed Skating    Speed Skating Women's 500 metres   NaN
#   ...                ...                                 ...   ...
#   69991    Speed Skating    Speed Skating Men's 1,000 metres   NaN
#   69994    Alpine Skiing        Alpine Skiing Men's Downhill   NaN
#   69995    Alpine Skiing    Alpine Skiing Men's Giant Slalom   NaN
#   69996    Alpine Skiing          Alpine Skiing Men's Slalom   NaN
#   69999  Nordic Combined          Nordic Combined Men's Team   NaN
#
#   [11533 rows x 15 columns])]

# %%
df.groupby('Season')['Height'].mean()
# Out:
# Season
# Summer    175.622797
# Winter    174.937696
# Name: Height, dtype: float64

# %%
df.groupby('Sex')['Height'].mean()
# Out:
# Sex
# F    167.92566
# M    178.80924
# Name: Height, dtype: float64

# %%
df.groupby('Sex')['Age'].mean()
# Out:
# Sex
# F    23.721287
# M    26.214509
# Name: Age, dtype: float64

# %%
sport_median_height = df.groupby('Sport')['Height'].median()
print(sport_median_height.min())
# Out:
# 164.0

# %%
print(sport_median_height.idxmin())
# Out:
# Gymnastics

# %%
sport_median_height[sport_median_height == 164.0]
# Out:
# Sport
# Gymnastics    164.0
# Name: Height, dtype: float64

# %%
country_gender_count = df.groupby(['NOC','Sex'])['ID'].count()
print(country_gender_count)
# Out:
# NOC  Sex
# AFG  M       38
# AHO  F        6
#      M       27
# ALB  F        4
#      M        7
#            ...
# YUG  M      455
# ZAM  F        3
#      M       40
# ZIM  F       41
#      M       47
# Name: ID, Length: 432, dtype: int64

# %%
country_gold_medals = df[df['Medal']=='Gold'].groupby('NOC')['Medal'].count()
print(country_gold_medals)
# Out:
# NOC
# ALG      1
# ANZ      7
# ARG     25
# ARM      1
# AUS     98
#       ...
# URU     13
# USA    747
# UZB      4
# YUG     31
# ZIM      7
# Name: Medal, Length: 84, dtype: int64

# %%
type(country_gold_medals)
# Out:
# pandas.core.series.Series

# %%
print(country_gold_medals.max())
# Out:
# 747

# %%
country_gold_medals[country_gold_medals== 747]
# Out:
# NOC
# USA    747
# Name: Medal, dtype: int64

# %%
sport_gender_avg_weight= df.groupby(['Sport','Sex'])['Weight'].mean()
print(sport_gender_avg_weight)
# Out:
# Sport          Sex
# Alpine Skiing  F      62.154589
#                M      77.725309
# Alpinism       F            NaN
#                M            NaN
# Archery        F      61.023256
#                         ...
# Water Polo     M      87.584973
# Weightlifting  F      66.189474
#                M      79.927852
# Wrestling      F      58.169014
#                M      77.256240
# Name: Weight, Length: 114, dtype: float64

# %%
print(sport_gender_avg_weight['Wrestling'])
# Out:
# Sex
# F    58.169014
# M    77.256240
# Name: Weight, dtype: float64

# %%
print(sport_gender_avg_weight['Wrestling']['M'])
# Out:
# 77.25624024960999

# %%
sport_event_count = df.groupby('Sport')['Event'].nunique().sort_values(ascending=False).head(10)
sport_event_count
# Out:
# Sport
# Athletics           83
# Shooting            81
# Swimming            54
# Cycling             42
# Sailing             37
# Wrestling           29
# Art Competitions    28
# Canoeing            27
# Gymnastics          26
# Rowing              25
# Name: Event, dtype: int64

# %%
sport_event_count.plot(kind='bar')
plt.title('Number of Unique Events per Sport')
plt.xlabel('Sport')
plt.ylabel("Number of Unique Events")
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(15,7))
year_participant_count = df.groupby('Year')['ID'].nunique()
year_participant_count.plot(kind='bar')
plt.title("Number of participants over the years")
plt.xlabel("Year")
plt.ylabel("Number of participants")
plt.show()

# %%
df[df['NOC']=='USA']
# Out:
#           ID                   Name Sex   Age  Height  Weight           Team  \
# 10         6        Per Knut Aaland   M  31.0   188.0    75.0  United States
# 11         6        Per Knut Aaland   M  31.0   188.0    75.0  United States
# 12         6        Per Knut Aaland   M  31.0   188.0    75.0  United States
# 13         6        Per Knut Aaland   M  31.0   188.0    75.0  United States
# 14         6        Per Knut Aaland   M  33.0   188.0    75.0  United States
# ...      ...                    ...  ..   ...     ...     ...            ...
# 69987  35653  Casey J. FitzRandolph   M  23.0   180.0    79.0  United States
# 69988  35653  Casey J. FitzRandolph   M  27.0   180.0    79.0  United States
# 69989  35653  Casey J. FitzRandolph   M  27.0   180.0    79.0  United States
# 69990  35653  Casey J. FitzRandolph   M  31.0   180.0    79.0  United States
# 69991  35653  Casey J. FitzRandolph   M  31.0   180.0    79.0  United States
#
#        NOC        Games  Year  Season            City                 Sport  \
# 10     USA  1992 Winter  1992  Winter     Albertville  Cross Country Skiing
# 11     USA  1992 Winter  1992  Winter     Albertville  Cross Country Skiing
# 12     USA  1992 Winter  1992  Winter     Albertville  Cross Country Skiing
# 13     USA  1992 Winter  1992  Winter     Albertville  Cross Country Skiing
# 14     USA  1994 Winter  1994  Winter     Lillehammer  Cross Country Skiing
# ...    ...          ...   ...     ...             ...                   ...
# 69987  USA  1998 Winter  1998  Winter          Nagano         Speed Skating
# 69988  USA  2002 Winter  2002  Winter  Salt Lake City         Speed Skating
# 69989  USA  2002 Winter  2002  Winter  Salt Lake City         Speed Skating
# 69990  USA  2006 Winter  2006  Winter          Torino         Speed Skating
# 69991  USA  2006 Winter  2006  Winter          Torino         Speed Skating
#
#                                                    Event Medal
# 10              Cross Country Skiing Men's 10 kilometres   NaN
# 11              Cross Country Skiing Men's 50 kilometres   NaN
# 12     Cross Country Skiing Men's 10/15 kilometres Pu...   NaN
# 13     Cross Country Skiing Men's 4 x 10 kilometres R...   NaN
# 14              Cross Country Skiing Men's 10 kilometres   NaN
# ...                                                  ...   ...
# 69987                   Speed Skating Men's 1,500 metres   NaN
# 69988                     Speed Skating Men's 500 metres  Gold
# 69989                   Speed Skating Men's 1,000 metres   NaN
# 69990                     Speed Skating Men's 500 metres   NaN
# 69991                   Speed Skating Men's 1,000 metres   NaN
#
# [5133 rows x 15 columns]

# %%
df.groupby('Age')['Height'].mean().sort_values(ascending=False).head(10)
# Out:
# Age
# 59.0    187.500000
# 57.0    184.750000
# 55.0    179.833333
# 61.0    177.500000
# 33.0    177.466801
# 29.0    177.185900
# 28.0    177.088074
# 34.0    176.882432
# 30.0    176.826367
# 31.0    176.747209
# Name: Height, dtype: float64

# %%
df.groupby("Age")['Height'].mean().sort_values(ascending=True).head(10)
# Out:
# Age
# 11.0    152.000000
# 62.0    157.000000
# 14.0    159.151042
# 15.0    161.838264
# 13.0    162.700000
# 12.0    164.250000
# 16.0    165.628129
# 17.0    169.691164
# 18.0    171.315822
# 54.0    171.470588
# Name: Height, dtype: float64

# %%
country_avg_age = df.groupby('NOC')['Age'].mean().sort_values(ascending=False)
country_avg_age.head(10).plot(kind='bar')
plt.title("Top 10 countries with highest average age of participants")
plt.xlabel('Country')
plt.ylabel('Average Age')
plt.xticks(rotation = 45)
plt.show()

# %%
country_avg_age = df.groupby("NOC")['Age'].mean().sort_values(ascending = False)
country_avg_age.tail(8).plot(kind='bar')
plt.title("Top 10 countries with highest average age of participants")
plt.xlabel('Country')
plt.ylabel('Average Age')
plt.xticks(rotation = 45)
plt.show()

# %%
sns.boxplot(data=df, x='Season', y='Age')
plt.title("Distribution of Ages by Season")
plt.xlabel("Season")
plt.ylabel("Age")
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.violinplot(data=df, x="Medal", y='Height', palette='Set2')
plt.title("Distribution of Heights by Medal")
plt.xlabel("Medal")
plt.ylabel("Height")
plt.show()

# %%
df['NOC'].value_counts().idxmax()
# Out:
# 'USA'

# %%
most_medals_count = df['NOC'].value_counts().idxmax()
print("Most Medal-Winning Country: ", most_medals_count)
# Out:
# Most Medal-Winning Country:  USA

# %%
df['NOC'].value_counts().index[0]
# Out:
# 'USA'

# %%
df['Height'].max()
# Out:
# 223.0

# %%
tallest_athlete = df[df['Height'] == df['Height'].max()]
print("Tallest Athlete:")
print(tallest_athlete[['ID','Name','Height','Sport']])
# Out:
# Tallest Athlete:
#           ID                  Name  Height       Sport
# 32376  16639  Tommy Loren Burleson   223.0  Basketball

# %%
heaviest_athlete = df[df['Weight'] == df['Weight'].max()]
print("Heaviest Athlete:")
print(heaviest_athlete[['ID','Name','Weight','Sport']])
# Out:
# Heaviest Athlete:
#           ID               Name  Weight Sport
# 23155  12177  Ricardo Blas, Jr.   214.0  Judo
# 23156  12177  Ricardo Blas, Jr.   214.0  Judo

# %%
lightest_athlete = df[df['Weight'] == df['Weight'].min()]
print("Lightest Athlete:")
print(lightest_athlete[['ID','Name','Weight','Sport']])
# Out:
# Lightest Athlete:
#           ID            Name  Weight       Sport
# 40849  21049  Choi Myong-Hui    25.0  Gymnastics
# 40850  21049  Choi Myong-Hui    25.0  Gymnastics
# 40851  21049  Choi Myong-Hui    25.0  Gymnastics
# 40852  21049  Choi Myong-Hui    25.0  Gymnastics
# 40853  21049  Choi Myong-Hui    25.0  Gymnastics
# 40854  21049  Choi Myong-Hui    25.0  Gymnastics

# %%
sns.scatterplot(data=df, x='Height', y='Weight', hue='Medal', palette='Set1')
plt.title("Athlete Height vs Weight by Medal Status")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.legend(title="Medal")
plt.show()
