# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DataSet/ecommerce_orders.csv')

# %%
df.head()
# Out:
#    OrderID  Customer_Age       City     Category    Product Name  Quantity  \
# 0  ORD1073          46.0  Bangalore       Beauty         Shampoo         2
# 1  ORD1067           NaN        NaN       Beauty         Shampoo         5
# 2  ORD1411         150.0  Bangalore         Toys            Doll        -1
# 3  ORD1477         150.0     Mumbai  Electronics      Power Bank         0
# 4  ORD1090           NaN  Bangalore  Electronics  Wireless Mouse         3
#
#     Price  Discount_pct Payment Method  Order_Date  Rating
# 0    7.73           NaN            UPI  26/05/2023     5.0
# 1   74.76           0.0           Cash  2023-04-16     NaN
# 2  163.06          20.0    Net Banking  01/05/2023     NaN
# 3   41.53           0.0            UPI  26/01/2024     5.0
# 4  238.75           0.0     Debit Card  2023-02-27     NaN

# %%
df.tail()
# Out:
#      OrderID  Customer_Age       City  Category Product Name  Quantity  \
# 560  ORD1457          -5.0  Hyderabad  Clothing       Jacket         1
# 561  ORD1361          44.0     Mumbai      Toys     Lego Set         5
# 562  ORD1440           NaN      Delhi    Beauty     Lipstick         4
# 563  ORD1175           NaN    Chennai      Toys         Doll         0
# 564  ORD1123         150.0      Delhi    Sports    Jump Rope         1
#
#       Price  Discount_pct Payment Method  Order_Date  Rating
# 560   10.62           0.0            UPI  2024-11-13     1.0
# 561  197.14           0.0    Credit Card  2023-11-20     4.0
# 562   45.27          15.0    Credit Card  2024-10-08     3.0
# 563  324.36           5.0            UPI  2023-05-02     NaN
# 564  162.41          20.0            UPI  22/03/2024     4.0

# %%
df.sample(10)
# Out:
#      OrderID  Customer_Age       City        Category Product Name  Quantity  \
# 413  ORD1425          55.0        NaN          Sports      Gym Bag         5
# 190  ORD1025          43.0      Delhi     Electronics       Webcam         1
# 389  ORD1319         150.0      Delhi            Toys       RC Car         1
# 5    ORD1346          52.0     Mumbai          Beauty   Face Cream         0
# 181  ORD1369           NaN     mumbai  Home & Kitchen   Frying Pan         1
# 6    ORD1514          -5.0    Chennai          Beauty    Face Mask         0
# 495  ORD1382         150.0     mumbai            Toys       Puzzle         4
# 401  ORD1003          24.0  Bangalore           Books     Notebook         1
# 130  ORD1263          63.0  Kathmandu     Electronics    USB Cable         1
# 400  ORD1426          40.0  Kathmandu     Electronics    USB Cable         1
#
#       Price  Discount_pct Payment Method  Order_Date  Rating
# 413   33.49           NaN            NaN  2023-09-07     NaN
# 190  230.75           5.0            NaN  10/07/2023     4.0
# 389   82.44          15.0    Credit Card  2024-09-01     4.0
# 5    309.85           0.0           Cash  2024-05-31     5.0
# 181  101.92           5.0            UPI  2023-05-22     NaN
# 6    433.70           0.0            UPI  2024-12-24     NaN
# 495  349.88           NaN            UPI  2023-09-20     NaN
# 401  367.34          20.0     Debit Card  2023-06-13     5.0
# 130   74.34           0.0           Cash  2023-02-23     2.0
# 400  277.02          10.0            UPI  2024-01-27     4.0

# %% [markdown]
# ###  **Column names** — inconsistent spacing/casing. Normalize to snake_case first, makes everything else easier.

# %%
df.columns
# Out:
# Index(['OrderID', 'Customer_Age', 'City', 'Category', 'Product Name',
#        'Quantity', 'Price', 'Discount_pct', 'Payment Method', 'Order_Date',
#        'Rating'],
#       dtype='object')

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(r'[^a-z0-9]+', '_', regex=True)
    .str.strip('_')
)
print(df.columns)
# Out:
# Index(['orderid', 'customer_age', 'city', 'category', 'product_name',
#        'quantity', 'price', 'discount_pct', 'payment_method', 'order_date',
#        'rating'],
#       dtype='object')

# %% [markdown]
# ### **Load + first look** — `.shape`, `.head()`, `.info()`, `.dtypes`. Get oriented before changing anything.

# %%
df.sample(5)
# Out:
#      orderid  customer_age       city        category    product_name  \
# 256  ORD1357          -5.0     mumbai     Electronics  Wireless Mouse
# 549  ORD1534          59.0      Delhi  Home & Kitchen   Cutting Board
# 133  ORD1176         150.0     Mumbai           Books        Textbook
# 160  ORD1498         150.0     Mumbai        Clothing        Sneakers
# 534  ORD1494          38.0  Bangalore  Home & Kitchen            Lamp
#
#      quantity   price  discount_pct payment_method  order_date  rating
# 256         2   18.12           0.0            NaN  2024-11-01     4.0
# 549         0  279.94          10.0            UPI  2024-08-11     NaN
# 133         4   91.31           0.0     Debit Card  27/05/2024     5.0
# 160         5   43.48           5.0           Cash  2024-04-30     1.0
# 534        -1   98.12           0.0            NaN  2023-05-19     3.0

# %%
df.shape
# Out:
# (565, 11)

# %%
df.head()
# Out:
#    orderid  customer_age       city     category    product_name  quantity  \
# 0  ORD1073          46.0  Bangalore       Beauty         Shampoo         2
# 1  ORD1067           NaN        NaN       Beauty         Shampoo         5
# 2  ORD1411         150.0  Bangalore         Toys            Doll        -1
# 3  ORD1477         150.0     Mumbai  Electronics      Power Bank         0
# 4  ORD1090           NaN  Bangalore  Electronics  Wireless Mouse         3
#
#     price  discount_pct payment_method  order_date  rating
# 0    7.73           NaN            UPI  26/05/2023     5.0
# 1   74.76           0.0           Cash  2023-04-16     NaN
# 2  163.06          20.0    Net Banking  01/05/2023     NaN
# 3   41.53           0.0            UPI  26/01/2024     5.0
# 4  238.75           0.0     Debit Card  2023-02-27     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   orderid         565 non-null    object
#  1   customer_age    439 non-null    float64
#  2   city            495 non-null    object
#  3   category        565 non-null    object
#  4   product_name    565 non-null    object
#  5   quantity        565 non-null    int64
#  6   price           565 non-null    float64
#  7   discount_pct    496 non-null    float64
#  8   payment_method  479 non-null    object
#  9   order_date      565 non-null    object
#  10  rating          417 non-null    float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 48.7+ KB

# %%
df.dtypes
# Out:
# orderid            object
# customer_age      float64
# city               object
# category           object
# product_name       object
# quantity            int64
# price             float64
# discount_pct      float64
# payment_method     object
# order_date         object
# rating            float64
# dtype: object

# %% [markdown]
# ###  **Missing values** — `.isna().sum()` to see where. Then per column, decide: drop, fill with mean/median/mode, fill "Unknown", or leave? Don't use the same strategy everywhere — justify each one.

# %%
df.isna().sum()
# Out:
# orderid             0
# customer_age      126
# city               70
# category            0
# product_name        0
# quantity            0
# price               0
# discount_pct       69
# payment_method     86
# order_date          0
# rating            148
# dtype: int64

# %%
df['customer_age'] = df['customer_age'].fillna(df['customer_age'].median())

# %%
df['city'] = df['city'].fillna("Unknown")

# %%
df['discount_pct'] = df['discount_pct'].fillna(0)

# %%
df['payment_method'] = df['payment_method'].fillna('Unknown')

# %%
df.isna().sum()
# Out:
# orderid             0
# customer_age        0
# city                0
# category            0
# product_name        0
# quantity            0
# price               0
# discount_pct        0
# payment_method      0
# order_date          0
# rating            148
# dtype: int64

# %% [markdown]
# ### **Duplicates**
#   - Full-row duplicates: `.duplicated()`
#   - Suspicious ID duplicates: same OrderID with *different* data in other columns — that's not a real duplicate, that's a data entry error. Check `.duplicated(subset=['OrderID'])` and inspect those rows.

# %%
df.duplicated().sum()
# Out:
# np.int64(13)

# %%
df[df.duplicated()]
# Out:
#      orderid  customer_age       city        category   product_name  \
# 150  ORD1161          46.0     mumbai            Toys  Action Figure
# 251  ORD1271          19.0  Bangalore  Home & Kitchen     Coffee Mug
# 289  ORD1313         150.0  Bangalore  Home & Kitchen           Lamp
# 307  ORD1296          -5.0      DELHI          Sports      Jump Rope
# 368  ORD1365         150.0  Kathmandu        Clothing       Sneakers
# 372  ORD1208         150.0  Bangalore          Sports       Dumbbell
# 393  ORD1136         150.0      DELHI            Toys           Doll
# 429  ORD1462          46.0     mumbai  Home & Kitchen           Lamp
# 430  ORD1066          20.0     mumbai            Toys  Action Figure
# 450  ORD1535          42.0     mumbai           Books          Comic
# 452  ORD1307         150.0     Mumbai          Beauty     Face Cream
# 472  ORD1424          -5.0      Delhi           Books          Novel
# 543  ORD1533         150.0    Unknown            Toys     Board Game
#
#      quantity   price  discount_pct payment_method  order_date  rating
# 150         2  187.05           0.0    Net Banking  20/05/2024     5.0
# 251         4  405.63           0.0           Cash  2024-08-05     2.0
# 289         0   17.55           0.0        Unknown  2024-05-06     5.0
# 307         3  263.51           0.0    Net Banking  2024-05-06     5.0
# 368         1  471.03           5.0    Credit Card  2024-02-24     4.0
# 372        -1  333.43          20.0           Cash  2024-04-29     1.0
# 393         1  164.99          15.0     Debit Card  2024-09-03     NaN
# 429         5  326.36           0.0     Debit Card  2023-10-09     2.0
# 430         2  273.63          10.0     Debit Card  2023-08-21     5.0
# 450         4  385.65          15.0     Debit Card  2024-08-27     NaN
# 452         3  260.57           0.0           Cash  2023-09-20     NaN
# 472        -1  249.74           0.0    Net Banking  2023-03-16     5.0
# 543         5  498.34           0.0    Credit Card  14/05/2024     5.0

# %%
df.duplicated(subset=['orderid']).sum()
# Out:
# np.int64(19)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated(subset=['orderid']).sum()
# Out:
# np.int64(6)

# %%
df[df.duplicated(subset=['orderid'])]
# Out:
#      orderid  customer_age       city     category product_name  quantity  \
# 124  ORD1226         150.0  Hyderabad  Electronics   Power Bank         2
# 222  ORD1001          -5.0      Delhi     Clothing        Jeans         0
# 284  ORD1001          41.0    Pokhara  Electronics   Power Bank         2
# 308  ORD1001          -5.0  Hyderabad        Books     Textbook         1
# 385  ORD1001         150.0     mumbai  Electronics    USB Cable         2
# 551  ORD1001         150.0      Delhi       Beauty   Face Cream         1
#
#       price  discount_pct payment_method  order_date  rating
# 124  125.77           0.0           Cash  2024-04-06     3.0
# 222  276.87          20.0    Credit Card  2024-08-25     2.0
# 284  275.08           0.0    Net Banking  2023-01-03     NaN
# 308  347.01           0.0    Net Banking  2023-12-02     5.0
# 385   41.65           0.0    Credit Card  2023-11-28     NaN
# 551  190.40           0.0        Unknown  2023-10-09     NaN

# %%
df[df['orderid'] == 'ORD1226']
# Out:
#      orderid  customer_age       city     category product_name  quantity  \
# 21   ORD1226         150.0  Hyderabad  Electronics   Power Bank         2
# 124  ORD1226         150.0  Hyderabad  Electronics   Power Bank         2
#
#        price  discount_pct payment_method  order_date  rating
# 21   6288.50           0.0           Cash  2024-04-06     3.0
# 124   125.77           0.0           Cash  2024-04-06     3.0

# %%
df = df.drop(124)

# %%
df[df['orderid'] == 'ORD1226']
# Out:
#     orderid  customer_age       city     category product_name  quantity  \
# 21  ORD1226         150.0  Hyderabad  Electronics   Power Bank         2
#
#      price  discount_pct payment_method  order_date  rating
# 21  6288.5           0.0           Cash  2024-04-06     3.0

# %%
df[df['orderid'] == 'ORD1001']
# Out:
#      orderid  customer_age       city     category product_name  quantity  \
# 84   ORD1001          -5.0      DELHI       Sports     Dumbbell         5
# 222  ORD1001          -5.0      Delhi     Clothing        Jeans         0
# 284  ORD1001          41.0    Pokhara  Electronics   Power Bank         2
# 308  ORD1001          -5.0  Hyderabad        Books     Textbook         1
# 385  ORD1001         150.0     mumbai  Electronics    USB Cable         2
# 551  ORD1001         150.0      Delhi       Beauty   Face Cream         1
#
#       price  discount_pct payment_method  order_date  rating
# 84   450.71           5.0    Credit Card  2023-10-01     5.0
# 222  276.87          20.0    Credit Card  2024-08-25     2.0
# 284  275.08           0.0    Net Banking  2023-01-03     NaN
# 308  347.01           0.0    Net Banking  2023-12-02     5.0
# 385   41.65           0.0    Credit Card  2023-11-28     NaN
# 551  190.40           0.0        Unknown  2023-10-09     NaN

# %%
df = df.drop([84,222,308,385,551])

# %%
df[df['orderid'] == 'ORD1001']
# Out:
#      orderid  customer_age     city     category product_name  quantity  \
# 284  ORD1001          41.0  Pokhara  Electronics   Power Bank         2
#
#       price  discount_pct payment_method  order_date  rating
# 284  275.08           0.0    Net Banking  2023-01-03     NaN

# %%
df.duplicated(subset=['orderid']).sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **Invalid values**

# %% [markdown]
# ### Ages: check `.describe()` / sort values — anything negative or above ~100 is garbage

# %%
df['customer_age'].describe()
# Out:
# count    546.000000
# mean      61.703297
# std       58.761373
# min       -5.000000
# 25%       19.250000
# 50%       46.000000
# 75%      150.000000
# max      150.000000
# Name: customer_age, dtype: float64

# %%
df['customer_age'].sort_values().head()
# Out:
# 215   -5.0
# 530   -5.0
# 306   -5.0
# 120   -5.0
# 122   -5.0
# Name: customer_age, dtype: float64

# %%
df['customer_age'].sort_values().tail()
# Out:
# 328    150.0
# 331    150.0
# 332    150.0
# 439    150.0
# 564    150.0
# Name: customer_age, dtype: float64

# %%
df[df['customer_age']< 0]
# Out:
#      orderid  customer_age       city        category   product_name  \
# 6    ORD1514          -5.0    Chennai          Beauty      Face Mask
# 10   ORD1475          -5.0      DELHI     Electronics   Laptop Stand
# 12   ORD1113          -5.0      Delhi        Clothing            Cap
# 22   ORD1339          -5.0     Mumbai        Clothing         Hoodie
# 30   ORD1486          -5.0  Hyderabad           Books          Comic
# ..       ...           ...        ...             ...            ...
# 541  ORD1031          -5.0     Mumbai  Home & Kitchen        Blender
# 545  ORD1487          -5.0     Mumbai     Electronics      USB Cable
# 548  ORD1150          -5.0    Pokhara  Home & Kitchen  Cutting Board
# 557  ORD1110          -5.0    Pokhara     Electronics      USB Cable
# 560  ORD1457          -5.0  Hyderabad        Clothing         Jacket
#
#      quantity   price  discount_pct payment_method  order_date  rating
# 6           0  433.70           0.0            UPI  2024-12-24     NaN
# 10          3  266.21           0.0     Debit Card  2023-06-09     4.0
# 12          5  465.20           0.0    Credit Card  10/03/2023     4.0
# 22          1  239.72          20.0     Debit Card  2024-11-28     3.0
# 30          0  451.07           0.0    Net Banking  2023-05-25     NaN
# ..        ...     ...           ...            ...         ...     ...
# 541         1  305.73           0.0            UPI  2024-10-11     3.0
# 545         2   27.50          15.0    Credit Card  2024-12-14     4.0
# 548        -1  142.93           0.0    Credit Card  2024-02-12     4.0
# 557         0   43.11          20.0    Net Banking  01/06/2023     NaN
# 560         1   10.62           0.0            UPI  2024-11-13     1.0
#
# [134 rows x 11 columns]

# %%
df[df['customer_age']> 100]
# Out:
#      orderid  customer_age       city        category   product_name  \
# 2    ORD1411         150.0  Bangalore            Toys           Doll
# 3    ORD1477         150.0     Mumbai     Electronics     Power Bank
# 8    ORD1363         150.0    Unknown            Toys  Action Figure
# 9    ORD1313         150.0  Bangalore  Home & Kitchen           Lamp
# 21   ORD1226         150.0  Hyderabad     Electronics     Power Bank
# ..       ...           ...        ...             ...            ...
# 553  ORD1127         150.0      Delhi  Home & Kitchen     Coffee Mug
# 555  ORD1045         150.0      Delhi          Sports       Dumbbell
# 556  ORD1314         150.0     mumbai  Home & Kitchen     Frying Pan
# 558  ORD1059         150.0     mumbai  Home & Kitchen           Lamp
# 564  ORD1123         150.0      Delhi          Sports      Jump Rope
#
#      quantity    price  discount_pct payment_method  order_date  rating
# 2          -1   163.06          20.0    Net Banking  01/05/2023     NaN
# 3           0    41.53           0.0            UPI  26/01/2024     5.0
# 8           5   231.84           0.0        Unknown  2023-12-06     5.0
# 9           0    17.55           0.0        Unknown  2024-05-06     5.0
# 21          2  6288.50           0.0           Cash  2024-04-06     3.0
# ..        ...      ...           ...            ...         ...     ...
# 553         1   409.92          15.0     Debit Card  2024-09-08     NaN
# 555         1   133.10           0.0           Cash  2024-11-02     4.0
# 556         5   481.51          15.0           Cash  2024-05-15     3.0
# 558         5    27.39           0.0        Unknown  2024-12-25     5.0
# 564         1   162.41          20.0            UPI  22/03/2024     4.0
#
# [152 rows x 11 columns]

# %%
df = df.drop(df[df['customer_age']< 0].index)

# %%
df = df.drop(df[df['customer_age']>100].index)

# %% [markdown]
# ### Quantity: 0 or negative doesn't make sense for an order — decide drop vs investigate
