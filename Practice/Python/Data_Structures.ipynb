# %% [markdown]
# ### List

# %%
integers = [4,5,6,7]  
integers
# Out:
# [4, 5, 6, 7]

# %%
type(integers)
# Out:
# list

# %%
lst = [1,2,3,4]

# %%
lst
# Out:
# [1, 2, 3, 4]

# %%
type(lst)
# Out:
# list

# %%
del lst

# %%
lst
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 lst
#
# NameError: name 'lst' is not defined

# %%
countries
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 countries
#
# NameError: name 'countries' is not defined

# %%
decimal = [4.55, 2.23, 5.45]
decimal
# Out:
# [4.55, 2.23, 5.45]

# %%
type(decimal)
# Out:
# list

# %%
mixed_data = [2,3,True,False, 'ok',5-3j,'hello',4.55,2.3,'nepal']
mixed_data
# Out:
# [2, 3, True, False, 'ok', (5-3j), 'hello', 4.55, 2.3, 'nepal']

# %%
type(mixed_data)
# Out:
# list

# %%
# Indexing and Slicing

# %%
mixed_data[4]
# Out:
# 'ok'

# %%
mixed_data[-6]
# Out:
# 'ok'

# %%
mixed_data
# Out:
# [2, 3, True, False, 'ok', (5-3j), 'hello', 4.55, 2.3, 'nepal']

# %%
mixed_data[::-1]
# Out:
# ['nepal', 2.3, 4.55, 'hello', (5-3j), 'ok', False, True, 3, 2]

# %%
mixed_data[1:18:2]
# Out:
# [3, False, (5-3j), 4.55, 'nepal']

# %%
# List is mutable --> changes can be made(add,remove,substitute)

# %%
# Adding the elements

# %%
mixed_data
# Out:
# [2, 3, True, False, 'ok', (5-3j), 'hello', 4.55, 2.3, 'nepal']

# %%
lst = mixed_data.copy()

# %%
lst
# Out:
# [2, 3, True, False, 'ok', (5-3j), 'hello', 4.55, 2.3, 'nepal']

# %%
# append, extend, insert

# %%
# append
lst.append(4)
lst
# Out:
# [2, 3, True, False, 'ok', (5-3j), 'hello', 4.55, 2.3, 'nepal', 4, 4, 4]

# %%
lst.append(3)
lst
# Out:
# [2, 3, True, False, 'ok', (5-3j), 'hello', 4.55, 2.3, 'nepal', 4, 4, 4, 3]

# %%
lst.append('hi')

# %%
lst
# Out:
# [2,
#  3,
#  True,
#  False,
#  'ok',
#  (5-3j),
#  'hello',
#  4.55,
#  2.3,
#  'nepal',
#  4,
#  4,
#  4,
#  3,
#  'hi']

# %%
# extend
lst.extend(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # extend
# ----> 2 lst.extend(1)
#
# TypeError: 'int' object is not iterable

# %%
lst
# Out:
# [2,
#  3,
#  True,
#  False,
#  'ok',
#  (5-3j),
#  'hello',
#  4.55,
#  2.3,
#  'nepal',
#  4,
#  4,
#  4,
#  3,
#  'hi']

# %%
lst.extend([7,8,9])

# %%
lst
# Out:
# [2,
#  3,
#  True,
#  False,
#  'ok',
#  (5-3j),
#  'hello',
#  4.55,
#  2.3,
#  'nepal',
#  4,
#  4,
#  4,
#  3,
#  'hi',
#  7,
#  8,
#  9]

# %%
lst.extend('python')

# %%
lst
# Out:
# [2,
#  3,
#  True,
#  False,
#  'ok',
#  (5-3j),
#  'hello',
#  4.55,
#  2.3,
#  'nepal',
#  4,
#  4,
#  4,
#  3,
#  'hi',
#  7,
#  8,
#  9,
#  'p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n']

# %%
# insert
lst = mixed_data.copy()

# %%
lst
# Out:
# [2, 3, True, False, 'ok', (5-3j), 'hello', 4.55, 2.3, 'nepal']

# %%
lst.insert(4,5)

# %%
lst
# Out:
# [2, 3, True, False, 5, 'ok', (5-3j), 'hello', 4.55, 2.3, 'nepal']

# %%
lst.insert(-4,'ok')

# %%
lst
# Out:
# [2, 3, True, False, 5, 'ok', (5-3j), 'ok', 'hello', 4.55, 2.3, 'nepal']

# %%
lst.insert(2,1)
lst
# Out:
# [2, 3, 1, True, False, 5, 'ok', (5-3j), 'ok', 'hello', 4.55, 2.3, 'nepal']

# %%
lst.insert(5,'hi')

# %%
lst
# Out:
# [2,
#  3,
#  1,
#  True,
#  False,
#  'hi',
#  5,
#  'ok',
#  (5-3j),
#  'ok',
#  'hello',
#  4.55,
#  2.3,
#  'nepal']

# %%
# Deleting the elements

# %%
lst = mixed_data.copy()

# %%
lst
# Out:
# [2, 3, True, False, 'ok', (5-3j), 'hello', 4.55, 2.3, 'nepal']

# %%
# pop
lst.pop()
# Out:
# 'nepal'

# %%
lst
# Out:
# [2, 3, True, False, 'ok', (5-3j), 'hello', 4.55, 2.3]

# %%
lst.pop(4)
# Out:
# 'ok'

# %%
lst
# Out:
# [2, 3, True, False, (5-3j), 'hello', 4.55, 2.3]

# %%
# remove
lst.remove(3)

# %%
lst
# Out:
# [2, True, False, (5-3j), 'hello', 4.55, 2.3]

# %%
lst.remove(2.3)

# %%
lst
# Out:
# [2, True, False, (5-3j), 'hello', 4.55]

# %%
lst.remove(1)
lst
# Out:
# [2, False, (5-3j), 'hello', 4.55]

# %%
lst.clear()

# %%
lst
# Out:
# []

# %%
lst = mixed_data.copy()

# %%
lst
# Out:
# [2, 3, True, False, 'ok', (5-3j), 'hello', 4.55, 2.3, 'nepal']

# %%
lst[3] = 33   # substitution
lst
# Out:
# [2, 3, True, 33, 'ok', (5-3j), 'hello', 4.55, 2.3, 'nepal']

# %%
lst[7] = 'vrit'
lst
# Out:
# [2, 3, True, 33, 'ok', (5-3j), 'hello', 'vrit', 2.3, 'nepal']

# %%
# sort
numbers = [4,5,1,11,66,44,21,33,18]
numbers
# Out:
# [4, 5, 1, 11, 66, 44, 21, 33, 18]

# %%
sorted(numbers)  # ascending order
# Out:
# [1, 4, 5, 11, 18, 21, 33, 44, 66]

# %%
numbers
# Out:
# [4, 5, 1, 11, 66, 44, 21, 33, 18]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 4, 5, 11, 18, 21, 33, 44, 66]

# %%
lst = [1,55,True,'hello',5.55]
lst
# Out:
# [1, 55, True, 'hello', 5.55]

# %%
lst[::-1]
# Out:
# [5.55, 'hello', True, 55, 1]

# %%
lst
# Out:
# [1, 55, True, 'hello', 5.55]

# %%
lst.reverse() # lst = lst[::-1]

# %%
lst
# Out:
# [5.55, 'hello', True, 55, 1]

# %%
numbers = [4,5,1,11,66,44,21,33,18]
numbers
# Out:
# [4, 5, 1, 11, 66, 44, 21, 33, 18]

# %%
len(numbers)
# Out:
# 9

# %%
len('kathmandu  ')
# Out:
# 11

# %%
numbers
# Out:
# [4, 5, 1, 11, 66, 44, 21, 33, 18]

# %%
numbers.index(11)
# Out:
# 3

# %%
numbers.count(1)
# Out:
# 1

# %%
g = [1,2,3,2,2,3,2,1,1]
g
# Out:
# [1, 2, 3, 2, 2, 3, 2, 1, 1]

# %%
g.index(3)
# Out:
# 2

# %%
g.index(1)
# Out:
# 0

# %%
g.index(2)
# Out:
# 1

# %%
g
# Out:
# [1, 2, 3, 2, 2, 3, 2, 1, 1]

# %%
g.count(1)
# Out:
# 3

# %%
g.count(2)
# Out:
# 4

# %%
g.count(3)
# Out:
# 2

# %%
g
# Out:
# [1, 2, 3, 2, 2, 3, 2, 1, 1]

# %%
len(g)
# Out:
# 9

# %%
even = [2,4,6,8]
odd = [1,3,5,7,9]

# %%
'kathmandu '+ 'nepal'
# Out:
# 'kathmandu nepal'

# %%
even + odd
# Out:
# [2, 4, 6, 8, 1, 3, 5, 7, 9]

# %%
even
# Out:
# [2, 4, 6, 8]

# %%
2 in even
# Out:
# True

# %%
7 in even
# Out:
# False

# %%
7 in odd
# Out:
# True

# %%
4 in odd
# Out:
# False

# %%
# empty list
lst = []
lst
# Out:
# []

# %%
type(lst)
# Out:
# list

# %% [markdown]
# ### Tuple

# %%
tpl = (2,3,4,5,6)
tpl
# Out:
# (2, 3, 4, 5, 6)

# %%
type(tpl)
# Out:
# tuple

# %%
tpl.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 tpl.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tpl.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tpl.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
tpl
# Out:
# (2, 3, 4, 5, 6)

# %%
tpl[2] = 55
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 tpl[2] = 55
#
# TypeError: 'tuple' object does not support item assignment

# %%
tpl
# Out:
# (2, 3, 4, 5, 6)

# %%
tpl[4]
# Out:
# 6

# %%
tpl[2]
# Out:
# 4

# %%
tpl[-3]
# Out:
# 4

# %%
tpl
# Out:
# (2, 3, 4, 5, 6)

# %%
tpl[::-1]
# Out:
# (6, 5, 4, 3, 2)

# %%
tpl[1:6:2]
# Out:
# (3, 5)

# %%
tpl
# Out:
# (2, 3, 4, 5, 6)

# %%
t1 = (3,4,5)
t2 = (1,2,3)
t1+t2   # duplicates are allowed
# Out:
# (3, 4, 5, 1, 2, 3)

# %%
t3 = ()
t3
# Out:
# ()

# %%
type(t3)
# Out:
# tuple

# %%
t1
# Out:
# (3, 4, 5)

# %%
# count
t1.count(4)
# Out:
# 1

# %%
t1.count(0)
# Out:
# 0

# %%
t1.index(5)
# Out:
# 2

# %%
t1
# Out:
# (3, 4, 5)

# %%
t = (4,5,6,7,8,9)
t
# Out:
# (4, 5, 6, 7, 8, 9)

# %%
type(t)
# Out:
# tuple

# %%
t.index(7)
# Out:
# 3

# %%
t = (1,2,3)
t
# Out:
# (1, 2, 3)

# %%
a,b,c = t

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
x,y,z = (7,8,9)
print(x)
print(y)
print(z)
# Out:
# 7
# 8
# 9

# %%
t
# Out:
# (1, 2, 3)

# %%
t*3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
(1,2)*8
# Out:
# (1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2, 1, 2)

# %%
t
# Out:
# (1, 2, 3)

# %%
3 in t
# Out:
# True

# %%
5 in t
# Out:
# False

# %% [markdown]
# ### SET

# %%
s1 = {}
s1
# Out:
# {}

# %%
type(s1)
# Out:
# dict

# %%
s1 = set()
s1
# Out:
# set()

# %%
type(s1)
# Out:
# set

# %%
s = {1,2,3,4,1,2,3,4,5,1,1,1}
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s1 = {12,3,4,5,6}
s2 = {5,6,7,8,9}

# %%
s1
# Out:
# {3, 4, 5, 6, 12}

# %%
s2
# Out:
# {5, 6, 7, 8, 9}

# %%
type(s1)
# Out:
# set

# %%
type(s2)
# Out:
# set

# %%
city = {'ktm','bkt','pkr'}
city
# Out:
# {'bkt', 'ktm', 'pkr'}

# %%
type(city)
# Out:
# set

# %%
city.add('btl')

# %%
city
# Out:
# {'bkt', 'btl', 'ktm', 'pkr'}

# %%
countries = {'nepal','china','india','japan','korea', 'russia'}
countries
# Out:
# {'china', 'india', 'japan', 'korea', 'nepal', 'russia'}

# %%
countries.add('usa')

# %%
countries
# Out:
# {'china', 'india', 'japan', 'korea', 'nepal', 'russia', 'usa'}

# %%
countries.discard('usa')

# %%
countries
# Out:
# {'china', 'india', 'japan', 'korea', 'nepal', 'russia'}

# %%
countries.add('germany')

# %%
countries
# Out:
# {'china', 'germany', 'india', 'japan', 'korea', 'nepal', 'russia'}

# %%
countries.remove('germany')

# %%
countries
# Out:
# {'china', 'india', 'japan', 'korea', 'nepal', 'russia'}

# %%
countries.discard('germany')

# %%
countries.remove('germany')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 countries.remove('germany')
#
# KeyError: 'germany'

# %%
countries
# Out:
# {'china', 'india', 'japan', 'korea', 'nepal', 'russia'}

# %%
countries.pop()
# Out:
# 'japan'

# %%
countries
# Out:
# {'china', 'india', 'korea', 'nepal', 'russia'}

# %%
countries.pop()
# Out:
# 'china'

# %%
countries
# Out:
# {'india', 'korea', 'nepal', 'russia'}

# %%
countries.clear()

# %%
countries
# Out:
# set()

# %%
a = {1,3,5,6,7,9}
b = {2,3,4,5}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9}

# %%
a.intersection(b)
# Out:
# {3, 5}

# %%
a
# Out:
# {1, 3, 5, 6, 7, 9}

# %%
b
# Out:
# {2, 3, 4, 5}

# %%
a|b #union
# Out:
# {1, 2, 3, 4, 5, 6, 7, 9}

# %%
a & b #intersection
# Out:
# {3, 5}

# %%
a
# Out:
# {1, 3, 5, 6, 7, 9}

# %%
b
# Out:
# {2, 3, 4, 5}

# %%
a.difference(b)
# Out:
# {1, 6, 7, 9}

# %%
b.difference(a)
# Out:
# {2, 4}

# %%
a
# Out:
# {1, 3, 5, 6, 7, 9}

# %%
{1,3}.issubset(a)
# Out:
# True

# %%
{2,5}.issubset(a)
# Out:
# False

# %%
countries = {'nepal','india','china'}
europe = ['uk','france','germany']
countries.update(europe)

# %%
countries
# Out:
# {'china', 'france', 'germany', 'india', 'nepal', 'uk'}

# %%
s = {1,2,3,4,'hi','nepal',[1,3]}  # elements inside the set should not be mutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 s = {1,2,3,4,'hi','nepal',[1,3]}  # elements inside the set should not be mutable
#
# TypeError: unhashable type: 'list'

# %%
s = {1,2,3,4,'hi','nepal',{1,3}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 s = {1,2,3,4,'hi','nepal',{1,3}}
#
# TypeError: unhashable type: 'set'

# %%
s = {1,2,3,4,'hi','nepal',(1,3)}

# %%
s
# Out:
# {(1, 3), 1, 2, 3, 4, 'hi', 'nepal'}

# %% [markdown]
# ### Type Conversion

# %%
lst = [1,2,3,4,5]
tpl = tuple(lst)

# %%
tpl
# Out:
# (1, 2, 3, 4, 5)

# %%
type(tpl)
# Out:
# tuple

# %%
list((4,5,6,7,8))
# Out:
# [4, 5, 6, 7, 8]

# %%
set([6,7,8,9])
# Out:
# {6, 7, 8, 9}

# %%
lst = [1,2,1,1,1,2,2,2,2,3,2,1,1,3]

# %%
lst= [1,1,1,1,2,2,2,3,3,3,4,1,1,2,2]
s1 = set(lst)
lst
# Out:
# [1, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 1, 1, 2, 2]

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,6}

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2
# Out:
# {4, 5, 6}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 3, 6}

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2
# Out:
# {4, 5, 6}

# %%
s1 | s2 # union
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1 & s2 # intersection
# Out:
# {4, 5}

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2
# Out:
# {4, 5, 6}

# %%
s1 - s2
# Out:
# {1, 2, 3}

# %%
s2 - s1
# Out:
# {6}

# %% [markdown]
# ### Frozenset

# %%
fs1 = frozenset({1,2,3,4,5,6})
fs1
# Out:
# frozenset({1, 2, 3, 4, 5, 6})

# %%
type(fs1)
# Out:
# frozenset

# %%
fs2 = frozenset({5,6,7,8,9})
fs2
# Out:
# frozenset({5, 6, 7, 8, 9})

# %%
fs1.add(9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 fs1.add(9)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
fs2.remove(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 fs2.remove(6)
#
# AttributeError: 'frozenset' object has no attribute 'remove'

# %%
fs1
# Out:
# frozenset({1, 2, 3, 4, 5, 6})

# %%
fs2
# Out:
# frozenset({5, 6, 7, 8, 9})

# %%
fs1 | fs2
# Out:
# frozenset({1, 2, 3, 4, 5, 6, 7, 8, 9})

# %%
fs1 & fs2
# Out:
# frozenset({5, 6})

# %%
fs1 - fs2
# Out:
# frozenset({1, 2, 3, 4})

# %%
fs1 ^ fs2
# Out:
# frozenset({1, 2, 3, 4, 7, 8, 9})

# %% [markdown]
# ### Dictionary

# %%
school = {}

# %%
type(school)
# Out:
# dict

# %%
school = {
    'name':'milan',
    'age': 27,
    'address': 'kathmandu',
    'roll': 5
}

# %%
type(school)
# Out:
# dict

# %%
school['name']
# Out:
# 'milan'

# %%
school['address']
# Out:
# 'kathmandu'

# %%
student = dict(
    name = 'milan',
    age = 27,
    address = 'kathmandu',
    roll = 5
)

# %%
type(student)
# Out:
# dict

# %%
student
# Out:
# {'name': 'milan', 'age': 27, 'address': 'kathmandu', 'roll': 5}

# %%
student['age']
# Out:
# 27

# %%
student['roll']
# Out:
# 5

# %%
s = {
    'a' : 5,
    'b' : 6,
    'a' : 7
} #keys must be unique

# %%
s
# Out:
# {'a': 7, 'b': 6}

# %%
s1 = {
    [1,2,3] : 5,
    'b' : 6,
    'a' : 7
} # keys must be immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 s1 = {
#       2     [1,2,3] : 5,
#       3     'b' : 6,
#       4     'a' : 7
#       5 } # keys must be immutable
#
# TypeError: unhashable type: 'list'

# %%
s1 = {
    (1,2,3) : 5,
    'b' : 6,
    'a' : 7
}

# %%
s1
# Out:
# {(1, 2, 3): 5, 'b': 6, 'a': 7}

# %%
s1[(1,2,3)]
# Out:
# 5

# %%
s1 = {
    'name' : 'ramesh',
    'address' : 'kathmandu'
}

# %%
s1
# Out:
# {'name': 'ramesh', 'address': 'kathmandu'}

# %%
s1['age'] = 30

# %%
s1
# Out:
# {'name': 'ramesh', 'address': 'kathmandu', 'age': 30}

# %%
s1.pop('address')
# Out:
# 'kathmandu'

# %%
s1
# Out:
# {'name': 'ramesh', 'age': 30}

# %%
s1['address']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 s1['address']
#
# KeyError: 'address'

# %%
s1.get('address')

# %%
s1
# Out:
# {'name': 'ramesh', 'age': 30}

# %%
s1['name']
# Out:
# 'ramesh'

# %%
s1.get('name')
# Out:
# 'ramesh'

# %%
s1
# Out:
# {'name': 'ramesh', 'age': 30}

# %%
s1.update({'location':'ktm', 'roll':25})

# %%
s1
# Out:
# {'name': 'ramesh', 'age': 30, 'location': 'ktm', 'roll': 25}

# %%
s1['name'] = 'bipin'

# %%
s1
# Out:
# {'name': 'bipin', 'age': 30, 'location': 'ktm', 'roll': 25}

# %%
d = {'name': 'ramesh', 'address': 'kathmandu', 'age': 30}
d
# Out:
# {'name': 'ramesh', 'address': 'kathmandu', 'age': 30}

# %%
d.pop('age')
# Out:
# 30

# %%
d
# Out:
# {'name': 'ramesh', 'address': 'kathmandu'}

# %%
d['grade'] = 'A+'
d['gpa'] = 3.8

# %%
d
# Out:
# {'name': 'ramesh', 'address': 'kathmandu', 'grade': 'A+', 'gpa': 3.8}

# %%
d.popitem()
# Out:
# ('gpa', 3.8)

# %%
d
# Out:
# {'name': 'ramesh', 'address': 'kathmandu', 'grade': 'A+'}

# %%
d.keys()
# Out:
# dict_keys(['name', 'address', 'grade'])

# %%
d.values()
# Out:
# dict_values(['ramesh', 'kathmandu', 'A+'])
