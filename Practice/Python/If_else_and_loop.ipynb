# %% [markdown]
# ## if, elif, else

# %%
'''
if condition:
  code
'''
# Out:
# '\nif condition:\n  code\n'

# %%
# indentation

# %%
3 < 8
# Out:
# True

# %%
if 3 < 8 :
    print('3 is less than 8')
# Out:
# 3 is less than 8

# %%
if 4 < 2:
    print('The condition is true')

# %%
age = 13
if  age >= 18:
    print('You can vote')

# %%
age = 33
if age >= 18:
    print('You can vote')
else:
    print("You can't vote")
# Out:
# You can vote

# %%
age = int(input('Enter your age:'))
if age >= 18:
    print('Adult')
else:
    print('Minor')
# Out:
# Minor

# %%
# interpreted vs complied programming language

# %%
number = int(input('Enter the number:'))
if number % 2 == 0:
    print('Even')
else:
    print('Odd')
# Out:
# Even

# %%
number = int(input('Enter the number:'))
if number % 2 == 0:
    print('Even')
elif number % 2 == 1:
    print('Odd')
# Out:
# Odd

# %%
bool(45)
# Out:
# True

# %%
bool(-33)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
age = int(input("Enter your age:"))
has_id = input('Enter True if you have ID otherwise, enter False:')
if age >= 18:
    print('Old Enough')
    if has_id == 'True':
        print('Id Verified -Welcome!')
    elif has_id == 'False':
        print('No ID sorry!')
else:
    print('Too young')
# Out:
# Too young

# %%
age = int(input('Enter your age:'))
has_id = input('Enter True if you have Id otherwise, enter False:')
if age >= 18 and has_id == 'True':
    print('You cam get license')
else:
    print('You cannot get license')
# Out:
# You cam get license

# %%
is_raining = True

if is_raining:
    print('Take Umbrella')
else:
    print('No umbrella')
# Out:
# Take Umbrella

# %%
username = input('Enter your name:').lower()
password = input('Enter your password:')
if username == 'ramesh' and password == 'python123':
    print('Login Successful! Welcome Ramesh!')
elif username == 'ramesh':
    print('Wrong password. Try again.')
else:
    print('Unknown user.')
# Out:
# Wrong password. Try again.

# %% [markdown]
# ### For Loop
