# %% [markdown]
# ### Keywords

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
abs(-10)
# Out:
# 10

# %%
divmod(15,2)
# Out:
# (7, 1)

# %%
divmod(17,4)
# Out:
# (4, 1)

# %% [markdown]
# ### Data Types
# int
#
# float
#
# str
#
# bool
#
# complex

# %% [markdown]
# ### int
#
# non-decimal numberic data

# %%
a = 8
b = 9
a+b
# Out:
# 17

# %%
c = a / b

# %%
c
# Out:
# 0.8888888888888888

# %%
type(c)
# Out:
# float

# %%
type(1)
# Out:
# int

# %%
type(a+b)
# Out:
# int

# %% [markdown]
# ### float
#
# decimal

# %%
a = 6.66
a
# Out:
# 6.66

# %%
type(a)
# Out:
# float

# %%
b = 5
r = a+b
print(r)
type(r)
# Out:
# 11.66
# float

# %% [markdown]
# ### string
#
# string is a character or group of characters enclosed inside single or double quotes

# %%
a = 'nepal'
a
# Out:
# 'nepal'

# %%
type(a)
# Out:
# str

# %%
b = 'vrit'
b
# Out:
# 'vrit'

# %%
type(b)
# Out:
# str

# %%
c = '123@abc&*'
c
# Out:
# '123@abc&*'

# %%
type(c)
# Out:
# str

# %%
d = '5'
d
# Out:
# '5'

# %%
type(d)
# Out:
# str

# %% [markdown]
# ### Indexing and Slicing in String

# %%
c = 'nepal'
c
# Out:
# 'nepal'

# %%
# Positive Indexing
# variable[index]
c[2]
# Out:
# 'p'

# %%
c[0]
# Out:
# 'n'

# %%
c[4]
# Out:
# 'l'

# %%
c[3]
# Out:
# 'a'

# %%
c[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 c[10]
#
# IndexError: string index out of range

# %%
# Negative Indexing
c[-1]
# Out:
# 'l'

# %%
c[-3]
# Out:
# 'p'

# %%
c[-5]
# Out:
# 'n'

# %%
c[-9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 c[-9]
#
# IndexError: string index out of range

# %% [markdown]
# ### Slicing
#
# variable[start:end:step]

# %%
a = 'baneshwor'
a
# Out:
# 'baneshwor'

# %%
a[3]
# Out:
# 'e'

# %%
a[-6]
# Out:
# 'e'

# %%
# variable[start:end:step]
a[1:6]  # end index is exclusive
# Out:
# 'anesh'

# %%
# default value of step is 1
a[1:6:1]
# Out:
# 'anesh'

# %%
a[4:]
# Out:
# 'shwor'

# %%
a
# Out:
# 'baneshwor'

# %%
a[1:8]
# Out:
# 'aneshwo'

# %%
a[1:8:2]
# Out:
# 'aeho'

# %%
a[1:8:-1]
# Out:
# ''

# %%
a[-7:-2:]
# Out:
# 'neshw'

# %%
a[-7:-1:-1]
# Out:
# ''

# %%
a[::2]
# Out:
# 'bnswr'

# %%
a[1::2]
# Out:
# 'aeho'

# %%
a
# Out:
# 'baneshwor'

# %%
a[::-1]
# Out:
# 'rowhsenab'

# %%
a[2::3]
# Out:
# 'nhr'

# %%
a[-1:-8:-1]
# Out:
# 'rowhsen'

# %%
a[::-2]
# Out:
# 'rwsnb'

# %%
a[::2]
# Out:
# 'bnswr'

# %% [markdown]
# ### String Methods

# %%
# variable.method()

# %%
a = 'hello'

# %%
a.upper()
# Out:
# 'HELLO'

# %%
b = "NEPAL"

# %%
b.lower()
# Out:
# 'nepal'

# %%
'    nepal      '.strip()
# Out:
# 'nepal'

# %%
"kathmandu bhaktapur lalitpur".split(" ")
# Out:
# ['kathmandu', 'bhaktapur', 'lalitpur']

# %%
'a,b,c,d,e'.split(",")
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
"nepalnepal".split('p')
# Out:
# ['ne', 'alne', 'al']

# %%
" ".join(['nepal','india','china'])
# Out:
# 'nepal india china'

# %%
c = 'nepal'

# %%
# string is immutable
c[0]= 's'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # string is immutable
# ----> 2 c[0]= 's'
#
# NameError: name 'c' is not defined

# %%
c
# Out:
# 'nepal'

# %%
c.replace('n','s')
# Out:
# 'sepal'

# %%
c
# Out:
# 'nepal'

# %%
c.find('l')
# Out:
# 4

# %%
"nepal".startswith('n')
# Out:
# True

# %%
'nepal'.startswith('o')
# Out:
# False

# %%
c = 'nepal'
print('The name of country is c')
# Out:
# The name of country is c

# %%
print(f'The name of country is {c}.')
# Out:
# The name of country is nepal.

# %%
name = 'Ram'
age = 25
print(f'My name is {name} and age is {age}')
# Out:
# My name is Ram and age is 25

# %%
1 == 1
# Out:
# True

# %%
True == 1
# Out:
# True

# %%
False == 0
# Out:
# True

# %%
isinstance(True, int)
# Out:
# True

# %%
isinstance(3, float)
# Out:
# False

# %%
isinstance(2.33, float)
# Out:
# True

# %%
isinstance(False, int)
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
# and --> True

# %%
False or False
# Out:
# False

# %%
True or False or False or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ### Complex

# %%
a = 7 - 4i
# Out:
#   Cell In[60], line 1
#     a = 7 - 4i
#             ^
# SyntaxError: invalid decimal literal

# %%
a = 7 - 4j

# %%
# attributes  --> variable.attribute
# methods --> variable.method()

# %%
a.real
# Out:
# 7.0

# %%
a.imag
# Out:
# -4.0

# %%
a.conjugate()
# Out:
# (7+4j)

# %%
b = complex(4,7)
b
# Out:
# (4+7j)

# %%
a
# Out:
# (7-4j)

# %%
a+b
# Out:
# (11+3j)

# %%
a
# Out:
# (7-4j)

# %%
b
# Out:
# (4+7j)

# %%
abs(b)
# Out:
# 8.06225774829855

# %% [markdown]
# ### Type Conversion

# %%
# int(), float(), str(), bool(), complex()

# %%
int(4.55)
# Out:
# 4

# %%
float(3)
# Out:
# 3.0

# %%
str(1234)
# Out:
# '1234'

# %%
type('3.45')
# Out:
# str

# %%
c = float('3.45')
c
# Out:
# 3.45

# %%
type(c)
# Out:
# float

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
complex(4,40)
# Out:
# (4+40j)

# %%
int('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 int('hello')
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
int('3.45')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 int('3.45')
#
# ValueError: invalid literal for int() with base 10: '3.45'

# %%
float('3.45')
# Out:
# 3.45

# %%
int('3.45')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 int('3.45')
#
# ValueError: invalid literal for int() with base 10: '3.45'

# %%
int('55')
# Out:
# 55

# %%
country = 'nepal '
capital = 'kathmandu'
country + capital   # concatenation
# Out:
# 'nepal kathmandu'

# %%
country*3
# Out:
# 'nepal nepal nepal '

# %%
country.title()
# Out:
# 'Nepal '

# %%
country
# Out:
# 'nepal '

# %%
'N' in country
# Out:
# False

# %%
# case-sensitive
'n' in country
# Out:
# True

# %%
'n' in 'sepal'
# Out:
# False

# %%
len(country)
# Out:
# 6

# %%
len('h    i')
# Out:
# 6

# %%
len('hi')
# Out:
# 2

# %%
v = 'nepal Is A very beautiful country'
v.title()
# Out:
# 'Nepal Is A Very Beautiful Country'

# %%
v.capitalize()
# Out:
# 'Nepal is a very beautiful country'

# %%
w = 'NePaL iS'
w.swapcase()
# Out:
# 'nEpAl Is'

# %%
l = '   baneshwor    '
l.strip()
# Out:
# 'baneshwor'

# %%
l.lstrip()
# Out:
# 'baneshwor    '

# %%
l.rstrip()
# Out:
# '   baneshwor'

# %%
r = 'kathmandu'

# %%
r.count('a')
# Out:
# 2

# %%
r.count('e')
# Out:
# 0

# %%
r.count('k')
# Out:
# 1

# %%
r
# Out:
# 'kathmandu'

# %%
r.index('h')
# Out:
# 3

# %%
r.index('n')
# Out:
# 6

# %%
r.index('z')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 r.index('z')
#
# ValueError: substring not found

# %%
r.find('z')
# Out:
# -1

# %%
r.find('h')
# Out:
# 3

# %%
'nepal'.index('p')
# Out:
# 2

# %%
'nepal'.find('p')
# Out:
# 2

# %%
'nepal'.index('q')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 'nepal'.index('q')
#
# ValueError: substring not found

# %%
'nepal'.find('q')
# Out:
# -1

# %%
'nepal'.isalpha()
# Out:
# True

# %%
'123nepal'.isalpha()
# Out:
# False

# %%
'123nepal'.isalnum()
# Out:
# True

# %%
'hi'.isalnum()
# Out:
# True

# %%
'456'.isalnum()
# Out:
# True

# %%
'456'.isdigit()
# Out:
# True

# %%
'abc123'.isdigit()
# Out:
# False

# %%
'    '.isspace()
# Out:
# True

# %%
'  1   '.isspace()
# Out:
# False

# %%
'hello'.islower()
# Out:
# True

# %%
greeting = "HELLO"
greeting.isupper() # "HELLO".isupper()
# Out:
# True

# %%
'hello Nepal'.istitle()
# Out:
# False

# %%
'Hello Nepal'.istitle()
# Out:
# True

# %%
name = 'Ram'
age = 25
print(f'My name is {name} and age is {age}')
# Out:
# My name is Ram and age is 25

# %%
print("My name is {} and age is {}".format(name,age))
# Out:
# My name is Ram and age is 25

# %%
print("My name is ", name,"and age is", age)
# Out:
# My name is  Ram and age is 25

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print("Hello\tWorld")
# Out:
# Hello	World

# %%
print('What's up')
# Out:
#   Cell In[153], line 1
#     print('What's up')
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('What\'s up')
# Out:
# What's up

# %%
print("What's up")
# Out:
# What's up

# %%
print(123)
# Out:
# 123

# %%
print(country)
# Out:
# nepal

# %%
a = input()

# %%
a
# Out:
# '10'

# %%
type(a)
# Out:
# str

# %%
first_number = int(input("Enter the first number:"))
first_number
# Out:
# 20

# %%
type(first_number)
# Out:
# int

# %%
int('55')
# Out:
# 55

# %%
first_number = float(input("Enter the first_number:"))
second_number = float(input("Enter the second_number:"))
sum = first_number + second_number
difference = first_number - second_number
multiplication = first_number * second_number
division = first_number / second_number

print(f'The sum of {first_number} and {second_number} is {sum}')
print(f'The difference of {first_number} and {second_number} is {difference}')
print(f'The product of {first_number} and {second_number} is {multiplication}')
print(f'The division of {first_number} and {second_number} is {division}')
# Out:
# The sum of 50.0 and 10.0 is 60.0
# The difference of 50.0 and 10.0 is 40.0
# The product of 50.0 and 10.0 is 500.0
# The division of 50.0 and 10.0 is 5.0

# %%
celcius = float(input('Enter the temperature in celcius:'))
fahrenheit = (celcius*9/5)+ 32
print(f'{celcius} is equal to {fahrenheit}')
# Out:
# 20.0 is equal to 68.0
